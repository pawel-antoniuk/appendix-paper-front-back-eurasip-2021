# %% [markdown]
# Sławomir Zieliński 2021
#
# Bialystok University of Technology

# %% [markdown]
# ## **Loop-Based Testing**

# %%
import os, shutil
import time, datetime, pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold, GroupKFold, LeaveOneGroupOut, GroupShuffleSplit, GridSearchCV, cross_val_score, train_test_split
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.pipeline import Pipeline
from sklearn import neighbors, linear_model, ensemble, svm
from sklearn import metrics
from xgboost import XGBClassifier, plot_importance, plot_tree, to_graphviz

# =========== Experiment type ===========
experiment_type = 'all'
classifier_type = 'xgboost'
test_type = 'hrtf-independent'


data_fname_blauert_bb = 'Blauert_Boosted_Bands_Features.csv'
data_fname_blauert_db = 'Blauert_Directional_Bands_Features.csv'
data_fname_hebrank_wright = 'Hebrank_and_Wright_Features.csv'
data_fname_langendijk_bronkhorst = 'Langendijk_and_Bronkhorst_Features.csv'

data_fname_lfcc = 'LFCC_30_Coeffs_Features.csv'
data_fname_binaural = 'Binaural_Features.csv'

data_dir = 'D:/FB Data/CSV'
results_dir = 'C:/Users/slawek/OneDrive/My Documents/Publications/2021/FB Paper/Results'
y_data_dir = 'C:/Users/slawek/OneDrive/My Documents/Publications/2021/FB Paper/y_data'
fig_dir = 'C:/Users/slawek/OneDrive/My Documents/Publications/2021/FB Paper/Figures'

n_scenes = 2 # 2 for 2-scenes scenario (front and back)
y_categories = [1, 2]
scene_labels = ['front', 'back']
labels_dict = {1:'front',2:'back'}

n_iterations = 7

# %% [markdown]
# ## Read and Convert Raw Data

# %%
# Read Blauert's boosted bands features first
db_raw = pd.read_csv(os.path.join(data_dir, data_fname_blauert_bb))

# Convert the first variable to category type
db_raw['fileNames'] = db_raw['fileNames'].astype('category')

print('Raw data shape:', db_raw.shape)
# Out:
# Raw data shape: (22496, 41)

# %%
# Create auxiliary variables for db_raw set
filenames = db_raw['fileNames'] 
recordings = []
hrtf_ids = []
hrtf_sources = [] # Institution, organization, e.g. MIT
scene_ids = []
scenes = []
augmentation_numbers = []

for filename in filenames:
    # print(filename)
    filename_split = filename.split('_')
    recordings.append(filename_split[0])
    if len(filename_split[1]) == 5:
        hrtf_ids.append(filename_split[1][-1])
    elif len(filename_split[1]) == 6:
        hrtf_ids.append(filename_split[1][-2:])
    hrtf_sources.append(filename_split[2])
    scene_ids.append(filename_split[3][-1])
    scenes.append(filename_split[4])
    augmentation_numbers.append(filename_split[5][-5])

# Create dataframe
descriptive_variables = pd.DataFrame(
    {'file_name': filenames,
     'recording': recordings,
     'hrtf_id': hrtf_ids,
     'hrtf_source': hrtf_sources,
     'scene_id': scene_ids,
     'scene': scenes,
     'augmentation': augmentation_numbers
    }, dtype='category')

db_raw = descriptive_variables.join(db_raw)
db_raw.drop(['fileNames'], inplace=True, axis=1) # Drop reduntant column
db_raw
# Out:
#                                                file_name  \
# 0      AClassicEducationNightOwl_hrtf10_listen_scene1...
# 1      AClassicEducationNightOwl_hrtf10_listen_scene2...
# 2      AClassicEducationNightOwl_hrtf11_listen_scene1...
# 3      AClassicEducationNightOwl_hrtf11_listen_scene2...
# 4      AClassicEducationNightOwl_hrtf12_listen_scene1...
# ...                                                  ...
# 22491     YouKnowBetter_hrtf7_sadie_scene2_back_aug1.wav
# 22492    YouKnowBetter_hrtf8_sadie_scene1_front_aug1.wav
# 22493     YouKnowBetter_hrtf8_sadie_scene2_back_aug1.wav
# 22494    YouKnowBetter_hrtf9_sadie_scene1_front_aug1.wav
# 22495     YouKnowBetter_hrtf9_sadie_scene2_back_aug1.wav
#
#                        recording hrtf_id hrtf_source scene_id  scene  \
# 0      AClassicEducationNightOwl      10      listen        1  front
# 1      AClassicEducationNightOwl      10      listen        2   back
# 2      AClassicEducationNightOwl      11      listen        1  front
# 3      AClassicEducationNightOwl      11      listen        2   back
# 4      AClassicEducationNightOwl      12      listen        1  front
# ...                          ...     ...         ...      ...    ...
# 22491              YouKnowBetter       7       sadie        2   back
# 22492              YouKnowBetter       8       sadie        1  front
# 22493              YouKnowBetter       8       sadie        2   back
# 22494              YouKnowBetter       9       sadie        1  front
# 22495              YouKnowBetter       9       sadie        2   back
#
#       augmentation   bb_x_m_1   bb_x_m_2   bb_x_m_3  ...  bb_mid_sd_1  \
# 0                1 -13.366475 -14.920718 -17.737867  ...     3.802044
# 1                1 -13.165625 -10.414157 -17.307292  ...     3.798409
# 2                1 -12.762384 -14.009565 -16.179163  ...     3.798318
# 3                1 -13.304450 -10.311370 -18.300599  ...     3.805799
# 4                1 -13.017466 -12.899031 -13.463031  ...     3.852681
# ...            ...        ...        ...        ...  ...          ...
# 22491            1 -10.551120 -18.346065 -27.321429  ...     3.889259
# 22492            1  -9.751750 -17.510771 -26.927838  ...     3.901691
# 22493            1  -9.196234 -15.621913 -26.735118  ...     3.868315
# 22494            1  -9.753131 -18.969621 -25.159916  ...     3.850202
# 22495            1  -9.410902 -16.400868 -27.669150  ...     3.861923
#
#        bb_mid_sd_2  bb_mid_sd_3  bb_mid_sd_4  bb_mid_sd_5  bb_side_sd_1  \
# 0         2.269497     3.698789     8.505135     9.932851      2.200164
# 1         2.320676     3.461247     8.166631    10.029490      2.595530
# 2         2.425447     2.874754     5.606093    10.087953      2.349373
# 3         2.346021     2.972628     5.591150     9.834396      2.514024
# 4         2.257683     3.522456     8.963307    10.148667      3.760871
# ...            ...          ...          ...          ...           ...
# 22491     4.557927     7.550142     9.794471    11.084363      4.029261
# 22492     4.580585     7.816229     8.925929    12.091808      3.508550
# 22493     4.845464     7.853752     9.887387    10.278599      3.547088
# 22494     4.237472     7.071604     7.851948    10.478471      3.737273
# 22495     4.516354     6.704111     7.120864    11.858271      3.755000
#
#        bb_side_sd_2  bb_side_sd_3  bb_side_sd_4  bb_side_sd_5
# 0          1.836064      2.989783      5.693024     10.150461
# 1          1.649154      2.443347      5.334224     10.355624
# 2          2.066034      3.479336      8.237912      9.867481
# 3          2.078017      3.515702      8.195845     10.214499
# 4          2.349555      2.855867      4.746690      9.648333
# ...             ...           ...           ...           ...
# 22491      3.950695      7.014002      7.092333     11.818726
# 22492      3.957277      6.589893      9.443778     11.187595
# 22493      3.853594      5.815141      7.218115     12.414284
# 22494      3.613938      6.905928      9.591553     11.980250
# 22495      3.900508      7.217094     10.206669     10.332471
#
# [22496 rows x 47 columns]

# %%
# Create additional auxiliary variables origin sources ('families') of HRTFs
hrtf_ids = db_raw['hrtf_id'].cat.categories.values
hrtf_sources = db_raw['hrtf_source'].cat.categories.values
hrtf_sources
# Out:
# array(['aachen', 'ari', 'cipic', 'clubfritz', 'hutubs', 'listen', 'mit',
#        'riec', 'sadie', 'scut', 'th-koln', 'tu-berlin', 'viking'],
#       dtype=object)

# %%
# # Remove Blauert's boosting bands
# db_raw.drop(db_raw.columns[np.arange(7,47)], axis=1, inplace=True)
# db_raw

# Read remaining datasets
db_raw_blauert_db = pd.read_csv(os.path.join(data_dir, data_fname_blauert_db))
db_raw_hebrank_wright = pd.read_csv(os.path.join(data_dir, data_fname_hebrank_wright))
db_raw_langendijk_bronkhorst = pd.read_csv(os.path.join(data_dir, data_fname_langendijk_bronkhorst))
db_raw_lfcc = pd.read_csv(os.path.join(data_dir, data_fname_lfcc))
db_raw_binaural = pd.read_csv(os.path.join(data_dir, data_fname_binaural))

db_raw_blauert_db.drop(['fileNames'], inplace=True, axis=1) # Drop reduntant column
db_raw_hebrank_wright.drop(['fileNames'], inplace=True, axis=1) # Drop reduntant column
db_raw_langendijk_bronkhorst.drop(['fileNames'], inplace=True, axis=1) # Drop reduntant column
db_raw_lfcc.drop(['fileNames'], inplace=True, axis=1) # Drop reduntant column
db_raw_binaural.drop(['fileNames'], inplace=True, axis=1) # Drop reduntant column

# Concatenate datasets
db_raw = db_raw.join([db_raw_blauert_db, db_raw_hebrank_wright, db_raw_langendijk_bronkhorst, db_raw_lfcc, db_raw_binaural])
# db_raw = db_raw.join([db_raw_blauert_db, db_raw_hebrank_wright, db_raw_langendijk_bronkhorst, db_raw_lfcc])
# db_raw = db_raw.join([db_raw_blauert_db, db_raw_hebrank_wright, db_raw_langendijk_bronkhorst, db_raw_binaural])
# db_raw = db_raw.join([db_raw_lfcc, db_raw_binaural])
db_raw
# Out:
#                                                file_name  \
# 0      AClassicEducationNightOwl_hrtf10_listen_scene1...
# 1      AClassicEducationNightOwl_hrtf10_listen_scene2...
# 2      AClassicEducationNightOwl_hrtf11_listen_scene1...
# 3      AClassicEducationNightOwl_hrtf11_listen_scene2...
# 4      AClassicEducationNightOwl_hrtf12_listen_scene1...
# ...                                                  ...
# 22491     YouKnowBetter_hrtf7_sadie_scene2_back_aug1.wav
# 22492    YouKnowBetter_hrtf8_sadie_scene1_front_aug1.wav
# 22493     YouKnowBetter_hrtf8_sadie_scene2_back_aug1.wav
# 22494    YouKnowBetter_hrtf9_sadie_scene1_front_aug1.wav
# 22495     YouKnowBetter_hrtf9_sadie_scene2_back_aug1.wav
#
#                        recording hrtf_id hrtf_source scene_id  scene  \
# 0      AClassicEducationNightOwl      10      listen        1  front
# 1      AClassicEducationNightOwl      10      listen        2   back
# 2      AClassicEducationNightOwl      11      listen        1  front
# 3      AClassicEducationNightOwl      11      listen        2   back
# 4      AClassicEducationNightOwl      12      listen        1  front
# ...                          ...     ...         ...      ...    ...
# 22491              YouKnowBetter       7       sadie        2   back
# 22492              YouKnowBetter       8       sadie        1  front
# 22493              YouKnowBetter       8       sadie        2   back
# 22494              YouKnowBetter       9       sadie        1  front
# 22495              YouKnowBetter       9       sadie        2   back
#
#       augmentation   bb_x_m_1   bb_x_m_2   bb_x_m_3  ...  ic_sd_ch_33  \
# 0                1 -13.366475 -14.920718 -17.737867  ...     0.023611
# 1                1 -13.165625 -10.414157 -17.307292  ...     0.017362
# 2                1 -12.762384 -14.009565 -16.179163  ...     0.052630
# 3                1 -13.304450 -10.311370 -18.300599  ...     0.034318
# 4                1 -13.017466 -12.899031 -13.463031  ...     0.054138
# ...            ...        ...        ...        ...  ...          ...
# 22491            1 -10.551120 -18.346065 -27.321429  ...     0.040642
# 22492            1  -9.751750 -17.510771 -26.927838  ...     0.048071
# 22493            1  -9.196234 -15.621913 -26.735118  ...     0.033712
# 22494            1  -9.753131 -18.969621 -25.159916  ...     0.047812
# 22495            1  -9.410902 -16.400868 -27.669150  ...     0.040928
#
#        ic_sd_ch_34  ic_sd_ch_35  ic_sd_ch_36  ic_sd_ch_37  ic_sd_ch_38  \
# 0         0.019060     0.018155     0.017408     0.012751     0.013184
# 1         0.013030     0.020101     0.016498     0.025959     0.026172
# 2         0.035431     0.031084     0.032807     0.041117     0.033306
# 3         0.018447     0.031849     0.044973     0.026626     0.044303
# 4         0.044948     0.029968     0.015117     0.022467     0.026151
# ...            ...          ...          ...          ...          ...
# 22491     0.038293     0.041630     0.036094     0.041333     0.042339
# 22492     0.044221     0.054130     0.049519     0.036272     0.031890
# 22493     0.039130     0.049905     0.037873     0.044492     0.044542
# 22494     0.040295     0.040516     0.041753     0.034353     0.038616
# 22495     0.037387     0.040182     0.029544     0.030674     0.046656
#
#        ic_sd_ch_39  ic_sd_ch_40  ic_sd_ch_41  ic_sd_ch_42
# 0         0.024904     0.028165     0.022075     0.014887
# 1         0.028664     0.023875     0.019687     0.018540
# 2         0.031166     0.041929     0.034703     0.029015
# 3         0.044530     0.042258     0.034486     0.022939
# 4         0.034298     0.043854     0.040078     0.036155
# ...            ...          ...          ...          ...
# 22491     0.045099     0.047074     0.049699     0.037355
# 22492     0.041308     0.055338     0.058114     0.058880
# 22493     0.041452     0.044125     0.050740     0.057483
# 22494     0.037940     0.040865     0.047759     0.049177
# 22495     0.038428     0.034006     0.031443     0.041261
#
# [22496 rows x 683 columns]

# %% [markdown]
# ### Summary statistics¶

# %%
n_all_features = db_raw.shape[1] - 7
print('Total number of features:',n_all_features)

db_raw.iloc[:,:7].describe(include = 'all').T
# Out:
# Total number of features: 676
#               count unique                                             top  \
# file_name     22496  22496  YouKnowBetter_hrtf9_sadie_scene2_back_aug1.wav
# recording     22496    152                                   YouKnowBetter
# hrtf_id       22496     74                                               9
# hrtf_source   22496     13                                          viking
# scene_id      22496      2                                               2
# scene         22496      2                                           front
# augmentation  22496      1                                               1
#
#                freq
# file_name         1
# recording       148
# hrtf_id         304
# hrtf_source    2128
# scene_id      11248
# scene         11248
# augmentation  22496

# %% [markdown]
# ## Train-Test Function

# %%
def random_train_test_split(recordings_list, seed):
    train_recordings, test_recordings = train_test_split(recordings_list, 
                                                     test_size=0.26,
                                                     random_state = seed)

    ind_train = db_raw['recording'].isin(train_recordings)
    ind_test = db_raw['recording'].isin(test_recordings)

    db_train = db_raw[ind_train]
    db_test = db_raw[ind_test]
    
    print('Train data shape:', db_train.shape)
    print('Test data shape:', db_test.shape)
    
    return db_train, db_test

# %% [markdown]
# ## Cross-Validation Setup

# %%
def my_kfold_cv(seed):
    n_splits = 10
    cv = KFold(n_splits=n_splits, shuffle=True, random_state=seed)
    cv_groups = []
    
    return cv, cv_groups

# %% [markdown]
# ## SGD Classifier Instantiation and Grid-Search Setup

# %%
# def sgd_setup():
    
#     classifier_sgd = linear_model.SGDClassifier(loss='hinge',
#                                                 alpha = 0.0001,
#                                                 random_state = seed)
    
#     k_best = SelectKBest(f_classif)
      
#     pipeline = Pipeline(steps=[('k_best', k_best),
#                                ('scaler', StandardScaler()), 
#                                ('sgd', classifier_sgd)]) 
#     k = ['all']
#     alpha_values = [0.00001, 0.0001, 0.001]
    
#     grid_search_parameters = {'k_best__k': k,
#                               'sgd__alpha': alpha_values}    
    
    
#     print(grid_search_parameters)
#     xgboost = False
    
#     return pipeline, grid_search_parameters

# %% [markdown]
# ## SVM Classifier Instantiation and Grid-Search Setup

# %%
# def svm_setup():

#     classifier_svm = svm.SVC(kernel = 'rbf',
#                              random_state = seed)

#     k_best = SelectKBest(f_classif)
      
#     pipeline = Pipeline(steps=[('k_best', k_best),
#                                ('scaler', StandardScaler()), 
#                                ('svm', classifier_svm)]) 

# #     k = ['all', int((3/4)*n_features/2), int((1/2)*n_features)]
# #     C_values = [0.1, 1, 10, 100, 1000]
# #     gamma_values = [1/n_features] * np.array([0.01, 0.1, 1, 10, 100])

#     k = ['all']
#     C_values = [0.1, 1, 10]
#     gamma_values = [1/n_features] 
    
#     grid_search_parameters = {'k_best__k': k,
#                               'svm__C': C_values,
#                               'svm__gamma': gamma_values}
    
#     print(grid_search_parameters)
#     xgboost = False
    
#     return pipeline, grid_search_parameters

# %% [markdown]
# ## Logistic Regression Classifier Instantiation and Grid-Search Setup

# %%
# def logit_setup():
#     print('\n\n============ Logit ===============')
#     classifier_logit = linear_model.LogisticRegression(penalty ='l1', 
#                                                        multi_class ='ovr', 
#                                                        solver = 'liblinear',
#                                                        intercept_scaling = 10,
#                                                        max_iter = 150,
#                                                        random_state = seed)
#     k_best = SelectKBest(f_classif)

#     pipeline = Pipeline(steps=[('k_best', k_best),
#                                ('scaler', StandardScaler()),
#                                ('logit', classifier_logit)]) 

#     # k = [200, 300, 500, 700]
#     # C_values = [0.1, 1, 10, 100]
   
#     k = ['all']
#     C_values = [0.01, 0.1, 1]
   
#     grid_search_parameters = {'k_best__k': k,
#                               'logit__C': C_values} 
#     print(grid_search_parameters)
#     xgboost_flag = False
    
#     return pipeline, grid_search_parameters

# %% [markdown]
# ## XGBoost Classifier Instantiation and Grid-Search Setup

# %%
def xgboost_setup():

    classifier_xgboost = XGBClassifier(random_state = seed,
                                       # tree_method = 'hist',
                                       tree_method = 'gpu_hist',
                                       # objective='multi:softmax',
                                       # num_class = 3,
                                       importance_type = 'gain')

    k_best = SelectKBest(f_classif)

    pipeline = Pipeline(steps=[('k_best', k_best),
                               ('scaler', StandardScaler()), 
                               ('xgboost', classifier_xgboost)]) 

    # k = [200, 300, 500, 700]
    # n_estimators = [100, 200, 500, 1000]

    k = ['all']
    n_estimators = [200]
    

    grid_search_parameters = {'k_best__k': k,
                              'xgboost__n_estimators': n_estimators}
    print(grid_search_parameters)
    xgboost_flag = True
    
    return pipeline, grid_search_parameters

# %% [markdown]
# ## Training function

# %%
def train(X_data, y_data, pipeline, grid_search_parameters, cv, cv_groups, xgboost_flag):
    
    if xgboost_flag == True: 
        n_jobs = 1
    else:                       
        n_jobs = 16

    grid_search = GridSearchCV(pipeline, 
                               grid_search_parameters, 
                               cv = cv, 
                               n_jobs = n_jobs,
                               scoring = 'accuracy',
                               # iid = False,
                               return_train_score = True)
    start_time = time.time()

    grid_search.fit(X_data, y_data)
    # grid_search.fit(X_data, y_data, groups = cv_groups)

    pd_results = pd.DataFrame(grid_search.cv_results_)
    means = grid_search.cv_results_['mean_test_score']
    stds = grid_search.cv_results_['std_test_score']
    params = grid_search.cv_results_['params']

    zipped = zip(means, stds, params)
    print('\nGrid search results:\n')
    for mean, std, params in sorted(zipped, key = lambda x: x[0]):
        print("%0.3f (+/-%0.03f) for %r"% (mean, std, params))

    print('\nBest parameters:', grid_search.best_params_)
    print('\nTrain CV acc: %0.3f  Test acc: %0.4f'% (grid_search.best_score_, grid_search.score(X_test, y_test)))
    print('\nTime elapsed (hh:mm:ss): ', datetime.timedelta(seconds=(time.time() - start_time)))
    
    return grid_search

# %% [markdown]
# ## Testing

# %%
# Accuracy report
def accuracy_report(y, y_pred):
    acc_test = metrics.accuracy_score(y, y_pred)
    print('\nTest metrics:')
    # print('Accuracy:', round(acc_test,3))
    print('Accuracy:', acc_test)
    print(metrics.classification_report(y, y_pred))
    return acc_test

# Confusion matrix
def confusion_mat(y, y_pred, labels):
    cm = metrics.confusion_matrix(y, y_pred, labels=labels)
    df_cm = pd.DataFrame(cm, columns=labels, index =labels)
    df_cm.index.name = 'Actual'
    df_cm.columns.name = 'Predicted'
    plt.figure(figsize = (6,4))
    sns.set(font_scale=1.4) # for label size
    sns.heatmap(df_cm, cmap="Blues", annot=True, annot_kws={"size": 16}, fmt='g', square=True)
    plt.ylim(len(labels), 0) # To prevent axis clipping effect
    plt.show()
    
# # Save pickle
# def save_pickle(data_name, fname, y_data_dir, experiment_type):
#     pickle_fname = os.path.join(y_data_dir, experiment_type, fname+'.pkl')
#     output_file = open(pickle_fname,'wb')
#     pickle.dump(data_name, output_file)
#     output_file.close()

# %% [markdown]
# ## Main Loop

# %%
start_time = time.time()
acc_test_across_iterations = []

for ii in range(n_iterations):
    
    print('\n\nIteration:',ii)
    
    seed = ii

    db_train, db_test = random_train_test_split(db_raw.recording.unique(), seed)   
    
    
    # HRTF-Independent Testing
   
    acc_test = []
    for hrtf_source in hrtf_sources:
        print('\n',hrtf_source)
        
        ind_train = db_train['hrtf_source'] == hrtf_source
        ind_test = db_test['hrtf_source'] == hrtf_source
        
        # ========== Selecting Feature Group ============
        selected_columns = np.array(range(7, 7+int(n_all_features))) # All features

        X_train, y_train = db_train.iloc[:,selected_columns], db_train.loc[:,'scene']
        X_test, y_test = db_test.iloc[:,selected_columns], db_test.loc[:,'scene']

        column_names = db_train.columns.values.tolist()

        n_features = len(selected_columns)
        print('Number of selected features:',n_features)
        print('X_train.shape =',X_train[~ind_train].shape)
        print('X_test.shape =',X_test[ind_test].shape)

        cv, cv_groups = my_kfold_cv(seed)

#         # sgd
#         pipeline, grid_search_parameters  = sgd_setup()
#         grid_search = train(X_train[~ind_train], y_train[~ind_train], pipeline, grid_search_parameters, cv, cv_groups, xgboost_flag = False)
               
#         # svm
#         pipeline, grid_search_parameters  = svm_setup()
#         grid_search = train(X_train[~ind_train], y_train[~ind_train], pipeline, grid_search_parameters, cv, cv_groups, xgboost_flag = False)

#         # Logit
#         pipeline, grid_search_parameters  = logit_setup()
#         grid_search = train(X_train[~ind_train], y_train[~ind_train], pipeline, grid_search_parameters, cv, cv_groups, xgboost_flag = False)

        # XGBoost 
        pipeline, grid_search_parameters  = xgboost_setup()
        grid_search = train(X_train[~ind_train], y_train[~ind_train], pipeline, grid_search_parameters, cv, cv_groups, xgboost_flag = True)

    
        # Predicting - Test data
        y_test_pred = grid_search.predict(X_test[ind_test])
        accuracy_report(y_test[ind_test], y_test_pred)
        # confusion_mat(y_test[ind_test], y_test_pred, scene_labels)
        acc_test.append(grid_search.score(X_test[ind_test], y_test[ind_test])) 
        
    acc_test_across_iterations.append(acc_test)
    
    print('\nMean accuracy:',np.mean(acc_test))    
    

# Convert to dataframe
acc_test_across_iterations = np.array(acc_test_across_iterations).T
acc_test_across_iterations_df = pd.DataFrame(acc_test_across_iterations, index=hrtf_sources)


# Save to CSV file
csv_full_fname = results_dir+'/'+experiment_type+' '+classifier_type+' '+test_type+'.csv'
acc_test_across_iterations_df.to_csv(csv_full_fname, index=True)   
    
    
print('\n+++++++ Total computation time (hh:mm:ss): ', datetime.timedelta(seconds=(time.time() - start_time)))
# print('Mean test accuracy:', np.mean(acc_test))
# Out:
# Iteration: 0
# Train data shape: (16576, 683)
# Test data shape: (5920, 683)
#
#  aachen
# Number of selected features: 676
# X_train.shape = (16128, 676)
# X_test.shape = (160, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.994 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.994  Test acc: 0.9758
#
# Time elapsed (hh:mm:ss):  0:00:30.014134
#
# Test metrics:
# Accuracy: 0.93125
#               precision    recall  f1-score   support
#
#         back       0.92      0.95      0.93        80
#        front       0.95      0.91      0.93        80
#
#     accuracy                           0.93       160
#    macro avg       0.93      0.93      0.93       160
# weighted avg       0.93      0.93      0.93       160
#
#
#  ari
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.994 (+/-0.003) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.994  Test acc: 0.9755
#
# Time elapsed (hh:mm:ss):  0:00:28.223284
#
# Test metrics:
# Accuracy: 0.9553571428571429
#               precision    recall  f1-score   support
#
#         back       0.96      0.95      0.96       280
#        front       0.95      0.96      0.96       280
#
#     accuracy                           0.96       560
#    macro avg       0.96      0.96      0.96       560
# weighted avg       0.96      0.96      0.96       560
#
#
#  cipic
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.995 (+/-0.003) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.995  Test acc: 0.9799
#
# Time elapsed (hh:mm:ss):  0:00:28.356514
#
# Test metrics:
# Accuracy: 0.9482142857142857
#               precision    recall  f1-score   support
#
#         back       0.94      0.96      0.95       280
#        front       0.96      0.94      0.95       280
#
#     accuracy                           0.95       560
#    macro avg       0.95      0.95      0.95       560
# weighted avg       0.95      0.95      0.95       560
#
#
#  clubfritz
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.994 (+/-0.003) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.994  Test acc: 0.9689
#
# Time elapsed (hh:mm:ss):  0:00:28.609559
#
# Test metrics:
# Accuracy: 0.9339285714285714
#               precision    recall  f1-score   support
#
#         back       0.88      1.00      0.94       280
#        front       1.00      0.87      0.93       280
#
#     accuracy                           0.93       560
#    macro avg       0.94      0.93      0.93       560
# weighted avg       0.94      0.93      0.93       560
#
#
#  hutubs
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.993 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.993  Test acc: 0.9775
#
# Time elapsed (hh:mm:ss):  0:00:28.355685
#
# Test metrics:
# Accuracy: 0.9464285714285714
#               precision    recall  f1-score   support
#
#         back       0.91      0.99      0.95       280
#        front       0.98      0.91      0.94       280
#
#     accuracy                           0.95       560
#    macro avg       0.95      0.95      0.95       560
# weighted avg       0.95      0.95      0.95       560
#
#
#  listen
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.993 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.993  Test acc: 0.9764
#
# Time elapsed (hh:mm:ss):  0:00:28.393413
#
# Test metrics:
# Accuracy: 0.9535714285714286
#               precision    recall  f1-score   support
#
#         back       0.95      0.96      0.95       280
#        front       0.96      0.95      0.95       280
#
#     accuracy                           0.95       560
#    macro avg       0.95      0.95      0.95       560
# weighted avg       0.95      0.95      0.95       560
#
#
#  mit
# Number of selected features: 676
# X_train.shape = (16128, 676)
# X_test.shape = (160, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.994 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.994  Test acc: 0.9777
#
# Time elapsed (hh:mm:ss):  0:00:29.385096
#
# Test metrics:
# Accuracy: 0.95625
#               precision    recall  f1-score   support
#
#         back       0.92      1.00      0.96        80
#        front       1.00      0.91      0.95        80
#
#     accuracy                           0.96       160
#    macro avg       0.96      0.96      0.96       160
# weighted avg       0.96      0.96      0.96       160
#
#
#  riec
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.993 (+/-0.003) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.993  Test acc: 0.9713
#
# Time elapsed (hh:mm:ss):  0:00:27.631765
#
# Test metrics:
# Accuracy: 0.9196428571428571
#               precision    recall  f1-score   support
#
#         back       0.93      0.90      0.92       280
#        front       0.91      0.94      0.92       280
#
#     accuracy                           0.92       560
#    macro avg       0.92      0.92      0.92       560
# weighted avg       0.92      0.92      0.92       560
#
#
#  sadie
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.993 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.993  Test acc: 0.9772
#
# Time elapsed (hh:mm:ss):  0:00:28.330458
#
# Test metrics:
# Accuracy: 0.9696428571428571
#               precision    recall  f1-score   support
#
#         back       0.95      1.00      0.97       280
#        front       1.00      0.94      0.97       280
#
#     accuracy                           0.97       560
#    macro avg       0.97      0.97      0.97       560
# weighted avg       0.97      0.97      0.97       560
#
#
#  scut
# Number of selected features: 676
# X_train.shape = (16128, 676)
# X_test.shape = (160, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.994 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.994  Test acc: 0.9738
#
# Time elapsed (hh:mm:ss):  0:00:29.320228
#
# Test metrics:
# Accuracy: 0.925
#               precision    recall  f1-score   support
#
#         back       0.97      0.88      0.92        80
#        front       0.89      0.97      0.93        80
#
#     accuracy                           0.93       160
#    macro avg       0.93      0.93      0.92       160
# weighted avg       0.93      0.93      0.92       160
#
#
#  th-koln
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.993 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.993  Test acc: 0.9595
#
# Time elapsed (hh:mm:ss):  0:00:27.461926
#
# Test metrics:
# Accuracy: 0.7946428571428571
#               precision    recall  f1-score   support
#
#         back       0.78      0.82      0.80       280
#        front       0.81      0.77      0.79       280
#
#     accuracy                           0.79       560
#    macro avg       0.80      0.79      0.79       560
# weighted avg       0.80      0.79      0.79       560
#
#
#  tu-berlin
# Number of selected features: 676
# X_train.shape = (15456, 676)
# X_test.shape = (400, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.993 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.993  Test acc: 0.9777
#
# Time elapsed (hh:mm:ss):  0:00:28.657683
#
# Test metrics:
# Accuracy: 0.9825
#               precision    recall  f1-score   support
#
#         back       0.98      0.98      0.98       200
#        front       0.98      0.98      0.98       200
#
#     accuracy                           0.98       400
#    macro avg       0.98      0.98      0.98       400
# weighted avg       0.98      0.98      0.98       400
#
#
#  viking
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.994 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.994  Test acc: 0.9758
#
# Time elapsed (hh:mm:ss):  0:00:27.767511
#
# Test metrics:
# Accuracy: 0.9428571428571428
#               precision    recall  f1-score   support
#
#         back       0.96      0.93      0.94       280
#        front       0.93      0.96      0.94       280
#
#     accuracy                           0.94       560
#    macro avg       0.94      0.94      0.94       560
# weighted avg       0.94      0.94      0.94       560
#
#
# Mean accuracy: 0.9353296703296704
#
#
# Iteration: 1
# Train data shape: (16576, 683)
# Test data shape: (5920, 683)
#
#  aachen
# Number of selected features: 676
# X_train.shape = (16128, 676)
# X_test.shape = (160, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.994 (+/-0.001) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.994  Test acc: 0.9765
#
# Time elapsed (hh:mm:ss):  0:00:29.479356
#
# Test metrics:
# Accuracy: 0.95
#               precision    recall  f1-score   support
#
#         back       0.94      0.96      0.95        80
#        front       0.96      0.94      0.95        80
#
#     accuracy                           0.95       160
#    macro avg       0.95      0.95      0.95       160
# weighted avg       0.95      0.95      0.95       160
#
#
#  ari
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.993 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.993  Test acc: 0.9775
#
# Time elapsed (hh:mm:ss):  0:00:28.195628
#
# Test metrics:
# Accuracy: 0.9553571428571429
#               precision    recall  f1-score   support
#
#         back       0.97      0.94      0.95       280
#        front       0.94      0.97      0.96       280
#
#     accuracy                           0.96       560
#    macro avg       0.96      0.96      0.96       560
# weighted avg       0.96      0.96      0.96       560
#
#
#  cipic
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.994 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.994  Test acc: 0.9809
#
# Time elapsed (hh:mm:ss):  0:00:27.903783
#
# Test metrics:
# Accuracy: 0.9428571428571428
#               precision    recall  f1-score   support
#
#         back       0.96      0.93      0.94       280
#        front       0.93      0.96      0.94       280
#
#     accuracy                           0.94       560
#    macro avg       0.94      0.94      0.94       560
# weighted avg       0.94      0.94      0.94       560
#
#
#  clubfritz
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.992 (+/-0.003) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.992  Test acc: 0.9767
#
# Time elapsed (hh:mm:ss):  0:00:28.231858
#
# Test metrics:
# Accuracy: 0.9696428571428571
#               precision    recall  f1-score   support
#
#         back       0.94      1.00      0.97       280
#        front       1.00      0.94      0.97       280
#
#     accuracy                           0.97       560
#    macro avg       0.97      0.97      0.97       560
# weighted avg       0.97      0.97      0.97       560
#
#
#  hutubs
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.993 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.993  Test acc: 0.9791
#
# Time elapsed (hh:mm:ss):  0:00:27.944141
#
# Test metrics:
# Accuracy: 0.9464285714285714
#               precision    recall  f1-score   support
#
#         back       0.95      0.94      0.95       280
#        front       0.94      0.95      0.95       280
#
#     accuracy                           0.95       560
#    macro avg       0.95      0.95      0.95       560
# weighted avg       0.95      0.95      0.95       560
#
#
#  listen
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.993 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.993  Test acc: 0.9779
#
# Time elapsed (hh:mm:ss):  0:00:28.074765
#
# Test metrics:
# Accuracy: 0.9535714285714286
#               precision    recall  f1-score   support
#
#         back       0.97      0.93      0.95       280
#        front       0.93      0.97      0.95       280
#
#     accuracy                           0.95       560
#    macro avg       0.95      0.95      0.95       560
# weighted avg       0.95      0.95      0.95       560
#
#
#  mit
# Number of selected features: 676
# X_train.shape = (16128, 676)
# X_test.shape = (160, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.994 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.994  Test acc: 0.9823
#
# Time elapsed (hh:mm:ss):  0:00:29.164313
#
# Test metrics:
# Accuracy: 0.9625
#               precision    recall  f1-score   support
#
#         back       0.97      0.95      0.96        80
#        front       0.95      0.97      0.96        80
#
#     accuracy                           0.96       160
#    macro avg       0.96      0.96      0.96       160
# weighted avg       0.96      0.96      0.96       160
#
#
#  riec
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.993 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.993  Test acc: 0.9764
#
# Time elapsed (hh:mm:ss):  0:00:27.863552
#
# Test metrics:
# Accuracy: 0.9339285714285714
#               precision    recall  f1-score   support
#
#         back       0.96      0.90      0.93       280
#        front       0.91      0.96      0.94       280
#
#     accuracy                           0.93       560
#    macro avg       0.94      0.93      0.93       560
# weighted avg       0.94      0.93      0.93       560
#
#
#  sadie
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.993 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.993  Test acc: 0.9797
#
# Time elapsed (hh:mm:ss):  0:00:28.134379
#
# Test metrics:
# Accuracy: 0.975
#               precision    recall  f1-score   support
#
#         back       0.97      0.99      0.98       280
#        front       0.99      0.96      0.97       280
#
#     accuracy                           0.97       560
#    macro avg       0.98      0.98      0.97       560
# weighted avg       0.98      0.97      0.97       560
#
#
#  scut
# Number of selected features: 676
# X_train.shape = (16128, 676)
# X_test.shape = (160, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.994 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.994  Test acc: 0.9782
#
# Time elapsed (hh:mm:ss):  0:00:29.287910
#
# Test metrics:
# Accuracy: 0.8875
#               precision    recall  f1-score   support
#
#         back       0.97      0.80      0.88        80
#        front       0.83      0.97      0.90        80
#
#     accuracy                           0.89       160
#    macro avg       0.90      0.89      0.89       160
# weighted avg       0.90      0.89      0.89       160
#
#
#  th-koln
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.994 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.994  Test acc: 0.9622
#
# Time elapsed (hh:mm:ss):  0:00:27.448952
#
# Test metrics:
# Accuracy: 0.8214285714285714
#               precision    recall  f1-score   support
#
#         back       0.81      0.83      0.82       280
#        front       0.83      0.81      0.82       280
#
#     accuracy                           0.82       560
#    macro avg       0.82      0.82      0.82       560
# weighted avg       0.82      0.82      0.82       560
#
#
#  tu-berlin
# Number of selected features: 676
# X_train.shape = (15456, 676)
# X_test.shape = (400, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.993 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.993  Test acc: 0.9791
#
# Time elapsed (hh:mm:ss):  0:00:28.999752
#
# Test metrics:
# Accuracy: 0.95
#               precision    recall  f1-score   support
#
#         back       0.98      0.92      0.95       200
#        front       0.92      0.98      0.95       200
#
#     accuracy                           0.95       400
#    macro avg       0.95      0.95      0.95       400
# weighted avg       0.95      0.95      0.95       400
#
#
#  viking
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.993 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.993  Test acc: 0.9767
#
# Time elapsed (hh:mm:ss):  0:00:27.782982
#
# Test metrics:
# Accuracy: 0.9464285714285714
#               precision    recall  f1-score   support
#
#         back       0.98      0.91      0.94       280
#        front       0.92      0.98      0.95       280
#
#     accuracy                           0.95       560
#    macro avg       0.95      0.95      0.95       560
# weighted avg       0.95      0.95      0.95       560
#
#
# Mean accuracy: 0.9380494505494503
#
#
# Iteration: 2
# Train data shape: (16576, 683)
# Test data shape: (5920, 683)
#
#  aachen
# Number of selected features: 676
# X_train.shape = (16128, 676)
# X_test.shape = (160, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.994 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.994  Test acc: 0.9846
#
# Time elapsed (hh:mm:ss):  0:00:29.596860
#
# Test metrics:
# Accuracy: 0.94375
#               precision    recall  f1-score   support
#
#         back       0.95      0.94      0.94        80
#        front       0.94      0.95      0.94        80
#
#     accuracy                           0.94       160
#    macro avg       0.94      0.94      0.94       160
# weighted avg       0.94      0.94      0.94       160
#
#
#  ari
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.994 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.994  Test acc: 0.9836
#
# Time elapsed (hh:mm:ss):  0:00:27.899056
#
# Test metrics:
# Accuracy: 0.9607142857142857
#               precision    recall  f1-score   support
#
#         back       0.99      0.93      0.96       280
#        front       0.94      0.99      0.96       280
#
#     accuracy                           0.96       560
#    macro avg       0.96      0.96      0.96       560
# weighted avg       0.96      0.96      0.96       560
#
#
#  cipic
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.995 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.995  Test acc: 0.9823
#
# Time elapsed (hh:mm:ss):  0:00:27.890164
#
# Test metrics:
# Accuracy: 0.9357142857142857
#               precision    recall  f1-score   support
#
#         back       0.92      0.95      0.94       280
#        front       0.95      0.92      0.93       280
#
#     accuracy                           0.94       560
#    macro avg       0.94      0.94      0.94       560
# weighted avg       0.94      0.94      0.94       560
#
#
#  clubfritz
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.994 (+/-0.001) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.994  Test acc: 0.9843
#
# Time elapsed (hh:mm:ss):  0:00:28.293082
#
# Test metrics:
# Accuracy: 0.975
#               precision    recall  f1-score   support
#
#         back       0.95      1.00      0.98       280
#        front       1.00      0.95      0.97       280
#
#     accuracy                           0.97       560
#    macro avg       0.98      0.97      0.97       560
# weighted avg       0.98      0.97      0.97       560
#
#
#  hutubs
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.994 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.994  Test acc: 0.9853
#
# Time elapsed (hh:mm:ss):  0:00:27.991485
#
# Test metrics:
# Accuracy: 0.9607142857142857
#               precision    recall  f1-score   support
#
#         back       0.95      0.97      0.96       280
#        front       0.97      0.95      0.96       280
#
#     accuracy                           0.96       560
#    macro avg       0.96      0.96      0.96       560
# weighted avg       0.96      0.96      0.96       560
#
#
#  listen
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.994 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.994  Test acc: 0.9848
#
# Time elapsed (hh:mm:ss):  0:00:28.040817
#
# Test metrics:
# Accuracy: 0.9660714285714286
#               precision    recall  f1-score   support
#
#         back       0.97      0.96      0.97       280
#        front       0.96      0.97      0.97       280
#
#     accuracy                           0.97       560
#    macro avg       0.97      0.97      0.97       560
# weighted avg       0.97      0.97      0.97       560
#
#
#  mit
# Number of selected features: 676
# X_train.shape = (16128, 676)
# X_test.shape = (160, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.994 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.994  Test acc: 0.9870
#
# Time elapsed (hh:mm:ss):  0:00:29.385152
#
# Test metrics:
# Accuracy: 0.9625
#               precision    recall  f1-score   support
#
#         back       0.97      0.95      0.96        80
#        front       0.95      0.97      0.96        80
#
#     accuracy                           0.96       160
#    macro avg       0.96      0.96      0.96       160
# weighted avg       0.96      0.96      0.96       160
#
#
#  riec
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.993 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.993  Test acc: 0.9834
#
# Time elapsed (hh:mm:ss):  0:00:27.868849
#
# Test metrics:
# Accuracy: 0.9464285714285714
#               precision    recall  f1-score   support
#
#         back       0.95      0.94      0.95       280
#        front       0.94      0.95      0.95       280
#
#     accuracy                           0.95       560
#    macro avg       0.95      0.95      0.95       560
# weighted avg       0.95      0.95      0.95       560
#
#
#  sadie
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.994 (+/-0.003) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.994  Test acc: 0.9850
#
# Time elapsed (hh:mm:ss):  0:00:28.014838
#
# Test metrics:
# Accuracy: 0.9803571428571428
#               precision    recall  f1-score   support
#
#         back       0.97      1.00      0.98       280
#        front       1.00      0.96      0.98       280
#
#     accuracy                           0.98       560
#    macro avg       0.98      0.98      0.98       560
# weighted avg       0.98      0.98      0.98       560
#
#
#  scut
# Number of selected features: 676
# X_train.shape = (16128, 676)
# X_test.shape = (160, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.993 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.993  Test acc: 0.9843
#
# Time elapsed (hh:mm:ss):  0:00:29.355755
#
# Test metrics:
# Accuracy: 0.925
#               precision    recall  f1-score   support
#
#         back       0.99      0.86      0.92        80
#        front       0.88      0.99      0.93        80
#
#     accuracy                           0.93       160
#    macro avg       0.93      0.93      0.92       160
# weighted avg       0.93      0.93      0.92       160
#
#
#  th-koln
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.994 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.994  Test acc: 0.9728
#
# Time elapsed (hh:mm:ss):  0:00:27.551464
#
# Test metrics:
# Accuracy: 0.8660714285714286
#               precision    recall  f1-score   support
#
#         back       0.84      0.90      0.87       280
#        front       0.89      0.83      0.86       280
#
#     accuracy                           0.87       560
#    macro avg       0.87      0.87      0.87       560
# weighted avg       0.87      0.87      0.87       560
#
#
#  tu-berlin
# Number of selected features: 676
# X_train.shape = (15456, 676)
# X_test.shape = (400, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.993 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.993  Test acc: 0.9858
#
# Time elapsed (hh:mm:ss):  0:00:28.740019
#
# Test metrics:
# Accuracy: 0.99
#               precision    recall  f1-score   support
#
#         back       0.99      0.98      0.99       200
#        front       0.99      0.99      0.99       200
#
#     accuracy                           0.99       400
#    macro avg       0.99      0.99      0.99       400
# weighted avg       0.99      0.99      0.99       400
#
#
#  viking
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.994 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.994  Test acc: 0.9824
#
# Time elapsed (hh:mm:ss):  0:00:28.036525
#
# Test metrics:
# Accuracy: 0.9482142857142857
#               precision    recall  f1-score   support
#
#         back       0.96      0.93      0.95       280
#        front       0.93      0.96      0.95       280
#
#     accuracy                           0.95       560
#    macro avg       0.95      0.95      0.95       560
# weighted avg       0.95      0.95      0.95       560
#
#
# Mean accuracy: 0.9508104395604396
#
#
# Iteration: 3
# Train data shape: (16576, 683)
# Test data shape: (5920, 683)
#
#  aachen
# Number of selected features: 676
# X_train.shape = (16128, 676)
# X_test.shape = (160, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.994 (+/-0.001) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.994  Test acc: 0.9858
#
# Time elapsed (hh:mm:ss):  0:00:29.410927
#
# Test metrics:
# Accuracy: 0.93125
#               precision    recall  f1-score   support
#
#         back       0.91      0.96      0.93        80
#        front       0.96      0.90      0.93        80
#
#     accuracy                           0.93       160
#    macro avg       0.93      0.93      0.93       160
# weighted avg       0.93      0.93      0.93       160
#
#
#  ari
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.993 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.993  Test acc: 0.9838
#
# Time elapsed (hh:mm:ss):  0:00:28.107172
#
# Test metrics:
# Accuracy: 0.9589285714285715
#               precision    recall  f1-score   support
#
#         back       0.99      0.93      0.96       280
#        front       0.93      0.99      0.96       280
#
#     accuracy                           0.96       560
#    macro avg       0.96      0.96      0.96       560
# weighted avg       0.96      0.96      0.96       560
#
#
#  cipic
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.994 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.994  Test acc: 0.9838
#
# Time elapsed (hh:mm:ss):  0:00:27.708166
#
# Test metrics:
# Accuracy: 0.9392857142857143
#               precision    recall  f1-score   support
#
#         back       0.93      0.95      0.94       280
#        front       0.95      0.93      0.94       280
#
#     accuracy                           0.94       560
#    macro avg       0.94      0.94      0.94       560
# weighted avg       0.94      0.94      0.94       560
#
#
#  clubfritz
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.993 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.993  Test acc: 0.9843
#
# Time elapsed (hh:mm:ss):  0:00:28.144574
#
# Test metrics:
# Accuracy: 0.975
#               precision    recall  f1-score   support
#
#         back       0.95      1.00      0.98       280
#        front       1.00      0.95      0.97       280
#
#     accuracy                           0.97       560
#    macro avg       0.98      0.97      0.97       560
# weighted avg       0.98      0.97      0.97       560
#
#
#  hutubs
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.994 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.994  Test acc: 0.9853
#
# Time elapsed (hh:mm:ss):  0:00:27.838437
#
# Test metrics:
# Accuracy: 0.9642857142857143
#               precision    recall  f1-score   support
#
#         back       0.96      0.97      0.96       280
#        front       0.97      0.96      0.96       280
#
#     accuracy                           0.96       560
#    macro avg       0.96      0.96      0.96       560
# weighted avg       0.96      0.96      0.96       560
#
#
#  listen
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.993 (+/-0.001) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.993  Test acc: 0.9860
#
# Time elapsed (hh:mm:ss):  0:00:27.978463
#
# Test metrics:
# Accuracy: 0.9589285714285715
#               precision    recall  f1-score   support
#
#         back       0.98      0.94      0.96       280
#        front       0.94      0.98      0.96       280
#
#     accuracy                           0.96       560
#    macro avg       0.96      0.96      0.96       560
# weighted avg       0.96      0.96      0.96       560
#
#
#  mit
# Number of selected features: 676
# X_train.shape = (16128, 676)
# X_test.shape = (160, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.993 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.993  Test acc: 0.9858
#
# Time elapsed (hh:mm:ss):  0:00:29.381185
#
# Test metrics:
# Accuracy: 0.96875
#               precision    recall  f1-score   support
#
#         back       0.99      0.95      0.97        80
#        front       0.95      0.99      0.97        80
#
#     accuracy                           0.97       160
#    macro avg       0.97      0.97      0.97       160
# weighted avg       0.97      0.97      0.97       160
#
#
#  riec
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.994 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.994  Test acc: 0.9836
#
# Time elapsed (hh:mm:ss):  0:00:27.924545
#
# Test metrics:
# Accuracy: 0.9571428571428572
#               precision    recall  f1-score   support
#
#         back       0.97      0.95      0.96       280
#        front       0.95      0.97      0.96       280
#
#     accuracy                           0.96       560
#    macro avg       0.96      0.96      0.96       560
# weighted avg       0.96      0.96      0.96       560
#
#
#  sadie
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.994 (+/-0.003) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.994  Test acc: 0.9838
#
# Time elapsed (hh:mm:ss):  0:00:27.996831
#
# Test metrics:
# Accuracy: 0.9785714285714285
#               precision    recall  f1-score   support
#
#         back       0.97      0.99      0.98       280
#        front       0.99      0.97      0.98       280
#
#     accuracy                           0.98       560
#    macro avg       0.98      0.98      0.98       560
# weighted avg       0.98      0.98      0.98       560
#
#
#  scut
# Number of selected features: 676
# X_train.shape = (16128, 676)
# X_test.shape = (160, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.994 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.994  Test acc: 0.9855
#
# Time elapsed (hh:mm:ss):  0:00:29.538366
#
# Test metrics:
# Accuracy: 0.9125
#               precision    recall  f1-score   support
#
#         back       1.00      0.82      0.90        80
#        front       0.85      1.00      0.92        80
#
#     accuracy                           0.91       160
#    macro avg       0.93      0.91      0.91       160
# weighted avg       0.93      0.91      0.91       160
#
#
#  th-koln
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.994 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.994  Test acc: 0.9699
#
# Time elapsed (hh:mm:ss):  0:00:27.337299
#
# Test metrics:
# Accuracy: 0.8339285714285715
#               precision    recall  f1-score   support
#
#         back       0.85      0.81      0.83       280
#        front       0.82      0.85      0.84       280
#
#     accuracy                           0.83       560
#    macro avg       0.83      0.83      0.83       560
# weighted avg       0.83      0.83      0.83       560
#
#
#  tu-berlin
# Number of selected features: 676
# X_train.shape = (15456, 676)
# X_test.shape = (400, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.993 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.993  Test acc: 0.9858
#
# Time elapsed (hh:mm:ss):  0:00:28.660330
#
# Test metrics:
# Accuracy: 0.9725
#               precision    recall  f1-score   support
#
#         back       0.99      0.95      0.97       200
#        front       0.95      0.99      0.97       200
#
#     accuracy                           0.97       400
#    macro avg       0.97      0.97      0.97       400
# weighted avg       0.97      0.97      0.97       400
#
#
#  viking
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.995 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.995  Test acc: 0.9861
#
# Time elapsed (hh:mm:ss):  0:00:27.868949
#
# Test metrics:
# Accuracy: 0.9696428571428571
#               precision    recall  f1-score   support
#
#         back       0.99      0.95      0.97       280
#        front       0.95      0.99      0.97       280
#
#     accuracy                           0.97       560
#    macro avg       0.97      0.97      0.97       560
# weighted avg       0.97      0.97      0.97       560
#
#
# Mean accuracy: 0.9477472527472527
#
#
# Iteration: 4
# Train data shape: (16576, 683)
# Test data shape: (5920, 683)
#
#  aachen
# Number of selected features: 676
# X_train.shape = (16128, 676)
# X_test.shape = (160, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.995 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.995  Test acc: 0.9865
#
# Time elapsed (hh:mm:ss):  0:00:29.394716
#
# Test metrics:
# Accuracy: 0.9625
#               precision    recall  f1-score   support
#
#         back       0.97      0.95      0.96        80
#        front       0.95      0.97      0.96        80
#
#     accuracy                           0.96       160
#    macro avg       0.96      0.96      0.96       160
# weighted avg       0.96      0.96      0.96       160
#
#
#  ari
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.992 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.992  Test acc: 0.9850
#
# Time elapsed (hh:mm:ss):  0:00:28.062809
#
# Test metrics:
# Accuracy: 0.9696428571428571
#               precision    recall  f1-score   support
#
#         back       0.99      0.95      0.97       280
#        front       0.95      0.99      0.97       280
#
#     accuracy                           0.97       560
#    macro avg       0.97      0.97      0.97       560
# weighted avg       0.97      0.97      0.97       560
#
#
#  cipic
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.993 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.993  Test acc: 0.9855
#
# Time elapsed (hh:mm:ss):  0:00:27.867204
#
# Test metrics:
# Accuracy: 0.9553571428571429
#               precision    recall  f1-score   support
#
#         back       0.94      0.97      0.96       280
#        front       0.97      0.94      0.95       280
#
#     accuracy                           0.96       560
#    macro avg       0.96      0.96      0.96       560
# weighted avg       0.96      0.96      0.96       560
#
#
#  clubfritz
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.992 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.992  Test acc: 0.9865
#
# Time elapsed (hh:mm:ss):  0:00:28.376193
#
# Test metrics:
# Accuracy: 0.9732142857142857
#               precision    recall  f1-score   support
#
#         back       0.95      1.00      0.97       280
#        front       1.00      0.95      0.97       280
#
#     accuracy                           0.97       560
#    macro avg       0.97      0.97      0.97       560
# weighted avg       0.97      0.97      0.97       560
#
#
#  hutubs
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.993 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.993  Test acc: 0.9845
#
# Time elapsed (hh:mm:ss):  0:00:28.112490
#
# Test metrics:
# Accuracy: 0.9589285714285715
#               precision    recall  f1-score   support
#
#         back       0.95      0.97      0.96       280
#        front       0.97      0.95      0.96       280
#
#     accuracy                           0.96       560
#    macro avg       0.96      0.96      0.96       560
# weighted avg       0.96      0.96      0.96       560
#
#
#  listen
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.993 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.993  Test acc: 0.9841
#
# Time elapsed (hh:mm:ss):  0:00:28.100999
#
# Test metrics:
# Accuracy: 0.9660714285714286
#               precision    recall  f1-score   support
#
#         back       0.99      0.95      0.97       280
#        front       0.95      0.99      0.97       280
#
#     accuracy                           0.97       560
#    macro avg       0.97      0.97      0.97       560
# weighted avg       0.97      0.97      0.97       560
#
#
#  mit
# Number of selected features: 676
# X_train.shape = (16128, 676)
# X_test.shape = (160, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.993 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.993  Test acc: 0.9875
#
# Time elapsed (hh:mm:ss):  0:00:29.454768
#
# Test metrics:
# Accuracy: 0.975
#               precision    recall  f1-score   support
#
#         back       0.96      0.99      0.98        80
#        front       0.99      0.96      0.97        80
#
#     accuracy                           0.97       160
#    macro avg       0.98      0.98      0.97       160
# weighted avg       0.98      0.97      0.97       160
#
#
#  riec
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.993 (+/-0.001) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.993  Test acc: 0.9838
#
# Time elapsed (hh:mm:ss):  0:00:27.746205
#
# Test metrics:
# Accuracy: 0.9375
#               precision    recall  f1-score   support
#
#         back       0.94      0.94      0.94       280
#        front       0.94      0.94      0.94       280
#
#     accuracy                           0.94       560
#    macro avg       0.94      0.94      0.94       560
# weighted avg       0.94      0.94      0.94       560
#
#
#  sadie
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.993 (+/-0.003) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.993  Test acc: 0.9870
#
# Time elapsed (hh:mm:ss):  0:00:28.224525
#
# Test metrics:
# Accuracy: 0.9803571428571428
#               precision    recall  f1-score   support
#
#         back       0.97      0.99      0.98       280
#        front       0.99      0.97      0.98       280
#
#     accuracy                           0.98       560
#    macro avg       0.98      0.98      0.98       560
# weighted avg       0.98      0.98      0.98       560
#
#
#  scut
# Number of selected features: 676
# X_train.shape = (16128, 676)
# X_test.shape = (160, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.993 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.993  Test acc: 0.9858
#
# Time elapsed (hh:mm:ss):  0:00:29.202623
#
# Test metrics:
# Accuracy: 0.9375
#               precision    recall  f1-score   support
#
#         back       0.99      0.89      0.93        80
#        front       0.90      0.99      0.94        80
#
#     accuracy                           0.94       160
#    macro avg       0.94      0.94      0.94       160
# weighted avg       0.94      0.94      0.94       160
#
#
#  th-koln
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# ...
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.993  Test acc: 0.9821
#
# Time elapsed (hh:mm:ss):  0:00:28.056058
#
# Test metrics:
# Accuracy: 0.9660714285714286
#               precision    recall  f1-score   support
#
#         back       0.99      0.95      0.97       280
#        front       0.95      0.99      0.97       280
#
#     accuracy                           0.97       560
#    macro avg       0.97      0.97      0.97       560
# weighted avg       0.97      0.97      0.97       560
#
#
#  mit
# Number of selected features: 676
# X_train.shape = (16128, 676)
# X_test.shape = (160, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.994 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.994  Test acc: 0.9843
#
# Time elapsed (hh:mm:ss):  0:00:29.288091
#
# Test metrics:
# Accuracy: 0.95
#               precision    recall  f1-score   support
#
#         back       0.99      0.91      0.95        80
#        front       0.92      0.99      0.95        80
#
#     accuracy                           0.95       160
#    macro avg       0.95      0.95      0.95       160
# weighted avg       0.95      0.95      0.95       160
#
#
#  riec
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.993 (+/-0.001) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.993  Test acc: 0.9811
#
# Time elapsed (hh:mm:ss):  0:00:28.061940
#
# Test metrics:
# Accuracy: 0.9339285714285714
#               precision    recall  f1-score   support
#
#         back       0.95      0.91      0.93       280
#        front       0.92      0.95      0.94       280
#
#     accuracy                           0.93       560
#    macro avg       0.93      0.93      0.93       560
# weighted avg       0.93      0.93      0.93       560
#
#
#  sadie
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.993 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.993  Test acc: 0.9848
#
# Time elapsed (hh:mm:ss):  0:00:28.309013
#
# Test metrics:
# Accuracy: 0.9875
#               precision    recall  f1-score   support
#
#         back       0.98      1.00      0.99       280
#        front       1.00      0.98      0.99       280
#
#     accuracy                           0.99       560
#    macro avg       0.99      0.99      0.99       560
# weighted avg       0.99      0.99      0.99       560
#
#
#  scut
# Number of selected features: 676
# X_train.shape = (16128, 676)
# X_test.shape = (160, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.994 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.994  Test acc: 0.9853
#
# Time elapsed (hh:mm:ss):  0:00:29.271833
#
# Test metrics:
# Accuracy: 0.91875
#               precision    recall  f1-score   support
#
#         back       1.00      0.84      0.91        80
#        front       0.86      1.00      0.92        80
#
#     accuracy                           0.92       160
#    macro avg       0.93      0.92      0.92       160
# weighted avg       0.93      0.92      0.92       160
#
#
#  th-koln
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.992 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.992  Test acc: 0.9709
#
# Time elapsed (hh:mm:ss):  0:00:27.810678
#
# Test metrics:
# Accuracy: 0.8232142857142857
#               precision    recall  f1-score   support
#
#         back       0.82      0.84      0.83       280
#        front       0.83      0.81      0.82       280
#
#     accuracy                           0.82       560
#    macro avg       0.82      0.82      0.82       560
# weighted avg       0.82      0.82      0.82       560
#
#
#  tu-berlin
# Number of selected features: 676
# X_train.shape = (15456, 676)
# X_test.shape = (400, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.993 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.993  Test acc: 0.9838
#
# Time elapsed (hh:mm:ss):  0:00:28.945583
#
# Test metrics:
# Accuracy: 0.9725
#               precision    recall  f1-score   support
#
#         back       0.99      0.95      0.97       200
#        front       0.96      0.99      0.97       200
#
#     accuracy                           0.97       400
#    macro avg       0.97      0.97      0.97       400
# weighted avg       0.97      0.97      0.97       400
#
#
#  viking
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.993 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.993  Test acc: 0.9824
#
# Time elapsed (hh:mm:ss):  0:00:27.999914
#
# Test metrics:
# Accuracy: 0.95
#               precision    recall  f1-score   support
#
#         back       0.99      0.91      0.95       280
#        front       0.92      0.99      0.95       280
#
#     accuracy                           0.95       560
#    macro avg       0.95      0.95      0.95       560
# weighted avg       0.95      0.95      0.95       560
#
#
# Mean accuracy: 0.9443131868131869
#
#
# Iteration: 6
# Train data shape: (16576, 683)
# Test data shape: (5920, 683)
#
#  aachen
# Number of selected features: 676
# X_train.shape = (16128, 676)
# X_test.shape = (160, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.994 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.994  Test acc: 0.9764
#
# Time elapsed (hh:mm:ss):  0:00:28.997161
#
# Test metrics:
# Accuracy: 0.93125
#               precision    recall  f1-score   support
#
#         back       0.93      0.94      0.93        80
#        front       0.94      0.93      0.93        80
#
#     accuracy                           0.93       160
#    macro avg       0.93      0.93      0.93       160
# weighted avg       0.93      0.93      0.93       160
#
#
#  ari
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.993 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.993  Test acc: 0.9757
#
# Time elapsed (hh:mm:ss):  0:00:27.843739
#
# Test metrics:
# Accuracy: 0.9607142857142857
#               precision    recall  f1-score   support
#
#         back       0.97      0.95      0.96       280
#        front       0.95      0.97      0.96       280
#
#     accuracy                           0.96       560
#    macro avg       0.96      0.96      0.96       560
# weighted avg       0.96      0.96      0.96       560
#
#
#  cipic
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.995 (+/-0.001) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.995  Test acc: 0.9731
#
# Time elapsed (hh:mm:ss):  0:00:27.786948
#
# Test metrics:
# Accuracy: 0.9410714285714286
#               precision    recall  f1-score   support
#
#         back       0.94      0.94      0.94       280
#        front       0.94      0.94      0.94       280
#
#     accuracy                           0.94       560
#    macro avg       0.94      0.94      0.94       560
# weighted avg       0.94      0.94      0.94       560
#
#
#  clubfritz
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.993 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.993  Test acc: 0.9725
#
# Time elapsed (hh:mm:ss):  0:00:27.757717
#
# Test metrics:
# Accuracy: 0.9428571428571428
#               precision    recall  f1-score   support
#
#         back       0.90      1.00      0.95       280
#        front       1.00      0.89      0.94       280
#
#     accuracy                           0.94       560
#    macro avg       0.95      0.94      0.94       560
# weighted avg       0.95      0.94      0.94       560
#
#
#  hutubs
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.994 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.994  Test acc: 0.9718
#
# Time elapsed (hh:mm:ss):  0:00:27.975912
#
# Test metrics:
# Accuracy: 0.9357142857142857
#               precision    recall  f1-score   support
#
#         back       0.92      0.96      0.94       280
#        front       0.96      0.91      0.93       280
#
#     accuracy                           0.94       560
#    macro avg       0.94      0.94      0.94       560
# weighted avg       0.94      0.94      0.94       560
#
#
#  listen
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.993 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.993  Test acc: 0.9740
#
# Time elapsed (hh:mm:ss):  0:00:27.817156
#
# Test metrics:
# Accuracy: 0.9553571428571429
#               precision    recall  f1-score   support
#
#         back       0.97      0.94      0.95       280
#        front       0.94      0.97      0.96       280
#
#     accuracy                           0.96       560
#    macro avg       0.96      0.96      0.96       560
# weighted avg       0.96      0.96      0.96       560
#
#
#  mit
# Number of selected features: 676
# X_train.shape = (16128, 676)
# X_test.shape = (160, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.994 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.994  Test acc: 0.9775
#
# Time elapsed (hh:mm:ss):  0:00:29.026905
#
# Test metrics:
# Accuracy: 0.95625
#               precision    recall  f1-score   support
#
#         back       0.94      0.97      0.96        80
#        front       0.97      0.94      0.96        80
#
#     accuracy                           0.96       160
#    macro avg       0.96      0.96      0.96       160
# weighted avg       0.96      0.96      0.96       160
#
#
#  riec
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.994 (+/-0.001) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.994  Test acc: 0.9693
#
# Time elapsed (hh:mm:ss):  0:00:27.565651
#
# Test metrics:
# Accuracy: 0.9107142857142857
#               precision    recall  f1-score   support
#
#         back       0.90      0.92      0.91       280
#        front       0.92      0.90      0.91       280
#
#     accuracy                           0.91       560
#    macro avg       0.91      0.91      0.91       560
# weighted avg       0.91      0.91      0.91       560
#
#
#  sadie
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.994 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.994  Test acc: 0.9757
#
# Time elapsed (hh:mm:ss):  0:00:27.865633
#
# Test metrics:
# Accuracy: 0.9696428571428571
#               precision    recall  f1-score   support
#
#         back       0.95      1.00      0.97       280
#        front       1.00      0.94      0.97       280
#
#     accuracy                           0.97       560
#    macro avg       0.97      0.97      0.97       560
# weighted avg       0.97      0.97      0.97       560
#
#
#  scut
# Number of selected features: 676
# X_train.shape = (16128, 676)
# X_test.shape = (160, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.994 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.994  Test acc: 0.9738
#
# Time elapsed (hh:mm:ss):  0:00:28.903617
#
# Test metrics:
# Accuracy: 0.9375
#               precision    recall  f1-score   support
#
#         back       0.99      0.89      0.93        80
#        front       0.90      0.99      0.94        80
#
#     accuracy                           0.94       160
#    macro avg       0.94      0.94      0.94       160
# weighted avg       0.94      0.94      0.94       160
#
#
#  th-koln
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.993 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.993  Test acc: 0.9632
#
# Time elapsed (hh:mm:ss):  0:00:27.250295
#
# Test metrics:
# Accuracy: 0.8339285714285715
#               precision    recall  f1-score   support
#
#         back       0.83      0.84      0.84       280
#        front       0.84      0.82      0.83       280
#
#     accuracy                           0.83       560
#    macro avg       0.83      0.83      0.83       560
# weighted avg       0.83      0.83      0.83       560
#
#
#  tu-berlin
# Number of selected features: 676
# X_train.shape = (15456, 676)
# X_test.shape = (400, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.993 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.993  Test acc: 0.9748
#
# Time elapsed (hh:mm:ss):  0:00:28.477451
#
# Test metrics:
# Accuracy: 0.96
#               precision    recall  f1-score   support
#
#         back       0.96      0.96      0.96       200
#        front       0.96      0.96      0.96       200
#
#     accuracy                           0.96       400
#    macro avg       0.96      0.96      0.96       400
# weighted avg       0.96      0.96      0.96       400
#
#
#  viking
# Number of selected features: 676
# X_train.shape = (15008, 676)
# X_test.shape = (560, 676)
# {'k_best__k': ['all'], 'xgboost__n_estimators': [200]}
#
# Grid search results:
#
# 0.994 (+/-0.002) for {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Best parameters: {'k_best__k': 'all', 'xgboost__n_estimators': 200}
#
# Train CV acc: 0.994  Test acc: 0.9767
#
# Time elapsed (hh:mm:ss):  0:00:27.621230
#
# Test metrics:
# Accuracy: 0.9642857142857143
#               precision    recall  f1-score   support
#
#         back       0.98      0.95      0.96       280
#        front       0.95      0.98      0.96       280
#
#     accuracy                           0.96       560
#    macro avg       0.96      0.96      0.96       560
# weighted avg       0.96      0.96      0.96       560
#
#
# Mean accuracy: 0.9384065934065933
#
# +++++++ Total computation time (hh:mm:ss):  0:43:19.749080

# %%
np.mean(acc_test)
# Out:
# 0.9384065934065933

# %%
acc_test_across_iterations_df.values.mean()
# Out:
# 0.9440600470957613

# %%
acc_test_across_iterations
# Out:
# array([[0.93125   , 0.95      , 0.94375   , 0.93125   , 0.9625    ,
#         0.94375   , 0.93125   ],
#        [0.95535714, 0.95535714, 0.96071429, 0.95892857, 0.96964286,
#         0.95535714, 0.96071429],
#        [0.94821429, 0.94285714, 0.93571429, 0.93928571, 0.95535714,
#         0.94642857, 0.94107143],
#        [0.93392857, 0.96964286, 0.975     , 0.975     , 0.97321429,
#         0.96785714, 0.94285714],
#        [0.94642857, 0.94642857, 0.96071429, 0.96428571, 0.95892857,
#         0.96071429, 0.93571429],
#        [0.95357143, 0.95357143, 0.96607143, 0.95892857, 0.96607143,
#         0.96607143, 0.95535714],
#        [0.95625   , 0.9625    , 0.9625    , 0.96875   , 0.975     ,
#         0.95      , 0.95625   ],
#        [0.91964286, 0.93392857, 0.94642857, 0.95714286, 0.9375    ,
#         0.93392857, 0.91071429],
#        [0.96964286, 0.975     , 0.98035714, 0.97857143, 0.98035714,
#         0.9875    , 0.96964286],
#        [0.925     , 0.8875    , 0.925     , 0.9125    , 0.9375    ,
#         0.91875   , 0.9375    ],
#        [0.79464286, 0.82142857, 0.86607143, 0.83392857, 0.82321429,
#         0.82321429, 0.83392857],
#        [0.9825    , 0.95      , 0.99      , 0.9725    , 0.99      ,
#         0.9725    , 0.96      ],
#        [0.94285714, 0.94642857, 0.94821429, 0.96964286, 0.96964286,
#         0.95      , 0.96428571]])
